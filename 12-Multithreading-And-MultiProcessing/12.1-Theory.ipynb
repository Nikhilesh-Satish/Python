# %% [markdown]
# - Program: A program is a sequence of instructions written in a programming language(Python, Java,C , C++,etc)

# %% [markdown]
# - Process: Instance of a program that is being executed

# %% [markdown]
# - Thread: Unit of execution within a process

# %% [markdown]
# - Single Threaded process - It will have its own stack and registers but will share code segment and heap from the process

# %% [markdown]
# - Multithreaded process - Same as single threaded but there are multiple units of execution
