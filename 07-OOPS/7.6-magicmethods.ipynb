# %% [markdown]
# ## Magic Methods

# %% [markdown]
# Magic methods in Python(dunder methods or double underscore methods), are special methods that start and end with double underscores. These methods enable you to define the behavior of objects for built in operations such as arithmetic operations, comparisons, etc.

# %% [markdown]
# Magic methods are predefined methods in Python that you can override to change the behavior of your objects

# %%
'''
Some magic methods:
__init__ : Constructor method to initialize object attributes
__str__ : String representation of the object
__add__ : Defines behavior for the + operator
__len__ : Defines behavior for the len() function
__repr__ : Official string representation of the object
__getitem__ : Defines behavior for indexing and slicing
__setitem__ : Defines behavior for setting values using indexing
'''
# Out:
# '\nSome magic methods:\n__init__ : Constructor method to initialize object attributes\n__str__ : String representation of the object\n__add__ : Defines behavior for the + operator\n__len__ : Defines behavior for the len() function\n__repr__ : Official string representation of the object\n__getitem__ : Defines behavior for indexing and slicing\n__setitem__ : Defines behavior for setting values using indexing\n'

# %%
class Person:
    pass

person=Person()
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
print(person)

# %%
## Basic methods
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
person=Person("ABCD",21)
print(person)

# %%
## Basic methods
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def __str__(self):
        return f"{self.name} is {self.age} years old"
    
    def __repr__(self):
        return f"Person(name={self.name},age={self.age})"
person=Person("ABCD",21)
print(person)
print(repr(person))
# Out:
# ABCD is 21 years old
# Person(name=ABCD,age=21)
