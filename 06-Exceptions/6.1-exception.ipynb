# %%
## Exceotion-try, except block

try:
    a=b
except:
    print("Variable is not assigned")
# Out:
# Variable is not assigned

# %%
try:
    a=b
except NameError as e:
    print(e)
# Out:
# name 'b' is not defined

# %%
try:
    result=1/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero
