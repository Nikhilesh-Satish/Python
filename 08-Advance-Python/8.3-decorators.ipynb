# %% [markdown]
# ## Decorators

# %% [markdown]
# Decorators allow you to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code

# %%
## Function copy
## Closures
## Decorators

# %%
## Function copy
def welcome():
    return "Welcome to Advanced Python"
welcome()
# Out:
# 'Welcome to Advanced Python'

# %%
wel=welcome
print(wel())
del welcome
print(wel())
# Out:
# Welcome to Advanced Python
# Welcome to Advanced Python

# %%
## Closures
def main_welcome():
    msg="Welcome"
    def sub_welcome_method():
        print("Welcome to advanced Python")
        print(msg)
        print("Please learn these methods properly")
    return sub_welcome_method()

# %%
main_welcome()
# Out:
# Welcome to advanced Python
# Welcome
# Please learn these methods properly
